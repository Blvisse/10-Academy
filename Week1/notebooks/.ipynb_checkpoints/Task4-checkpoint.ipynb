# %%
import pandas as pd
import numpy as np
import seaborn as sns 
import matplotlib.pyplot as plt
from scipy import stats 

sns.set_theme()

# %%
data=pd.read_csv('../data/experienceAnalysis.csv')

# %%
data['Engagement Cluster'].value_counts()
# Out:
# 0    70484
# 1     9739
# Name: Engagement Cluster, dtype: int64

# %%
calculateData=data.drop(labels=['MSISDN/Number','IMEI','Handset Manufacturer','Last Location Name','IMSI','Bearer Id','Handset Type'],axis=1)

# %%
lowEngagement=calculateData.loc[data['Engagement Cluster']==0]
highEngagement=calculateData.loc[data['Engagement Cluster']==1]

# %%
lowEngagement.head()
# Out:
#    Engagement Cluster  Dur. (ms).1  Avg RTT DL (ms)  Avg RTT UL (ms)  \
# 0                   0      1167.20        46.000000         0.000000
# 1                   0      1812.30        30.000000         1.000000
# 2                   0      1349.69       109.795706        17.662883
# 3                   0       498.78        69.000000        15.000000
# 4                   0      1280.88        21.000000         3.000000
#
#    Avg Bearer TP DL (kbps)  Avg Bearer TP UL (kbps)  \
# 0                     37.0                     39.0
# 1                     48.0                     51.0
# 2                     48.0                     49.0
# 3                    204.0                     44.0
# 4                   7463.0                    324.0
#
#    TCP DL Retrans. Vol (Bytes)  TCP UL Retrans. Vol (Bytes)  HTTP DL (Bytes)  \
# 0                 2.080991e+07                759658.664811     1.144710e+08
# 1                 2.080991e+07                759658.664811     1.144710e+08
# ...

# %%
from sklearn.metrics.pairwise import euclidean_distances
euclidean_distances(highEngagement.head(),lowEngagement.head())
# arry=cdist(data[10:],lowEngagement[10:],metric='euclidean')
# Out:
# array([[5.89564308e+08, 1.42728091e+09, 5.51019415e+08, 1.26974504e+09,
#         1.44863335e+09],
#        [1.27275479e+09, 8.42076351e+08, 7.19706434e+08, 1.14800190e+09,
#         9.18292466e+08],
#        [5.90689789e+08, 9.51303169e+08, 6.66153500e+07, 8.03051506e+08,
#         9.65348365e+08],
#        [5.62050754e+08, 9.61851548e+08, 4.75969150e+08, 4.59150772e+08,
#         9.13900712e+08],
#        [3.92177557e+08, 1.12415340e+09, 4.89179042e+08, 6.33119993e+08,
#         1.08143764e+09]])

# %%
lowEngagement[100:]
# Out:
#        MSISDN/Number  Engagement Cluster                       Handset Type  \
# 110     3.360126e+10                   0                          undefined
# 111     3.360126e+10                   0     Huawei P20 Lite Huawei Nova 3E
# 112     3.360126e+10                   0     Huawei P20 Lite Huawei Nova 3E
# 115     3.360127e+10                   0             Apple iPhone 7 (A1778)
# 117     3.360127e+10                   0             Apple iPhone X (A1901)
# ...              ...                 ...                                ...
# 80218   3.378996e+10                   0  Samsung Galaxy S8 Plus (Sm-G955F)
# 80219   3.378997e+10                   0            Apple iPhone 6S (A1688)
# 80220   3.379000e+10                   0                Huawei Honor 9 Lite
# 80221   3.379000e+10                   0        Apple iPhone 8 Plus (A1897)
# 80222   3.370000e+14                   0                   Huawei B525S-23A
#
# ...

# %%
from scipy.spatial.distance import pdist

array1=pdist(lowEngagement[:10000],highEngagement[:1000],'euclid')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-53-610c24124fc8> in <module>
#       1 from scipy.spatial.distance import pdist
#       2
# ----> 3 array1=pdist(lowEngagement[:10000],highEngagement[:1000],'euclid')
#
# C:\ProgramData\Anaconda3\lib\site-packages\scipy\spatial\distance.py in pdist(X, metric, *args, **kwargs)
#    2032
#    2033     # compute blocklist for deprecated kwargs
# -> 2034     if(metric in _METRICS['jensenshannon'].aka
#    2035        or metric == 'test_jensenshannon' or metric == jensenshannon):
#    2036         kwargs_blocklist = ["p", "w", "V", "VI"]
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\generic.py in __nonzero__(self)
#    1441     def __nonzero__(self):
#    1442         raise ValueError(
# -> 1443             f"The truth value of a {type(self).__name__} is ambiguous. "
# ...

# %%
array2=pdist(data[['Total Session (Mbs)','Engagement Cluster']].values[:20000],'euclid')

# %%
array3=pdist(data[['Total Session (Mbs)','Engagement Cluster']].values[:30000],'euclid')

# %%
array4=pdist(data[['Total Session (Mbs)','Engagement Cluster']].values[:40000],'euclid')

# %%
array5=pdist(data[['Total Session (Mbs)','Engagement Cluster']].values[:50000],'euclid')

# %%
array6=pdist(data[['Total Session (Mbs)','Engagement Cluster']].values[:6000],'euclid')

# %%
array7=pdist(data[['Total Session (Mbs)','Engagement Cluster']].values[:7000],'euclid')

# %%
array8=pdist(data[['Total Session (Mbs)','Engagement Cluster']].values[:8000],'euclid')
