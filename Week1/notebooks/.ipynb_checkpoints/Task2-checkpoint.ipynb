# %% [markdown]
# ## Import Libraries

# %%
import pandas as pd
import numpy as np
import seaborn as sns 
import matplotlib.pyplot as plt
from scipy import stats 

sns.set_theme()

# %%
import sys
import os


module_path =os.path.abspath(os.path.join('..'))
if module_path not in sys.path:
    sys.path.append(module_path+"\\scripts")

if module_path not in sys.path:
    sys.path.append(module_path+"\\models")

# %%
from univariate import Univariate,readCSV
from loaddata import ReadData
from aggregarefunctions import aggregateClass
from knn import Models

# %% [markdown]
# ## Read Dataset

# %%
dataRead=ReadData('../data/processed_data3.csv')
data=dataRead.readCsv()
# Out:
# Reading Data...
#
# Successfully read the dataset ...

# %%
data.head()
# Out:
#               Bearer Id                Start  Dur. (ms)          IMSI  \
# 0  13114483460844900352  2019-04-04 12:01:18  1823652.0  2.082014e+14
# 1  13114483482878900224  2019-04-09 13:04:04  1365104.0  2.082019e+14
# 2  13114483484080500736  2019-04-09 17:42:11  1361762.0  2.082003e+14
# 3  13114483485442799616  2019-04-10 00:31:25  1321509.0  2.082014e+14
# 4  13114483499480700928  2019-04-12 20:10:23  1089009.0  2.082014e+14
#
#    MSISDN/Number          IMEI Last Location Name  Avg RTT DL (ms)  \
# 0   3.366496e+10  3.552121e+13   9164566995485190        42.000000
# 1   3.368185e+10  3.579401e+13            L77566A        65.000000
# 2   3.376063e+10  3.528151e+13            D42335A       109.795706
# 3   3.375034e+10  3.535661e+13            T21824A       109.795706
# 4   3.369980e+10  3.540701e+13            D88865A       109.795706
#
#    Avg RTT UL (ms)  Avg Bearer TP DL (kbps)  ...  Netflix Total (Bytes)  \
# 0         5.000000                     23.0  ...             17855187.0
# 1         5.000000                     16.0  ...             35565545.0
# 2        17.662883                      6.0  ...             23751202.0
# 3        17.662883                     44.0  ...             15092588.0
# 4        17.662883                      6.0  ...             17539799.0
#
#    Gaming Total (Bytes)  Other Total (Bytes)  Avg Bearer TP DL (Mbps)  \
# 0           292426453.0          180558843.0                 0.022461
# 1           609920783.0          541959383.0                 0.015625
# 2           229980251.0          414908351.0                 0.005859
# 3           810387875.0          761837216.0                 0.042969
# 4           531237049.0          564619822.0                 0.005859
#
#    Avg Bearer TP UL (Mbps)  Activity Duration DL (s)  \
# 0                 0.042969                    37.624
# 1                 0.025391                     0.168
# 2                 0.008789                     0.000
# 3                 0.042969                     3.330
# 4                 0.008789                     0.000
#
#    Activity Duration UL (s)  Total UL+DL (Bytes) Total Session (Mbs)  \
# 0                    38.787          345629377.0          493.406131
# 1                     3.560          707185356.0         1176.919550
# 2                     0.000          307690973.0          685.103951
# 3                    37.882          889352748.0         1562.493020
# 4                     0.000          607681403.0         1104.727653
#
#   Duration Class
# 0        Outlier
# 1        Outlier
# 2        Outlier
# 3        Outlier
# 4        Outlier
#
# [5 rows x 50 columns]

# %% [markdown]
# **User Metrics to Track**
# *	sessions frequency
# *	the duration of the session
# *	the sessions total traffic (download and upload (bytes))

# %%
#create a constructor for our python aggregateClass script
aggFunc=aggregateClass(data)

# %% [markdown]
# ## Top Customers per Engagement

# %% [markdown]
# ### Session Frequency

# %% [markdown]
# We calculate this metric by getting the total number of xDR session per user. A user is identified by a unique **MSISDN/Number**

# %%
userData=data.groupby(['MSISDN/Number'])['Bearer Id'].nunique().sort_values(ascending=False)
userData=pd.DataFrame(userData)
userData.columns=['No of xDR sessions']

sessionData=userData['No of xDR sessions']

userData.head(10)
# Out:
#                No of xDR sessions
# MSISDN/Number
# 3.362632e+10                   18
# 3.361489e+10                   17
# 3.362578e+10                   17
# 3.365973e+10                   16
# 3.376054e+10                   15
# 3.367588e+10                   15
# 3.366716e+10                   14
# 3.362708e+10                   12
# 3.376041e+10                   12
# 3.360313e+10                   12

# %%
sessionDF=pd.DataFrame(sessionData)

# %%
sessionDF['MSISDN/Number']=sessionDF.index

# %%
sessionDF.reset_index(drop=True,inplace=True)

# %%
sessionDF
# Out:
#         No of xDR sessions  MSISDN/Number
# 0                       18   3.362632e+10
# 1                       17   3.361489e+10
# 2                       17   3.362578e+10
# 3                       16   3.365973e+10
# 4                       15   3.376054e+10
# ...                    ...            ...
# 106851                   1   3.366069e+10
# 106852                   1   3.366069e+10
# 106853                   1   3.366069e+10
# 106854                   1   3.366069e+10
# 106855                   1   8.823971e+14
#
# [106856 rows x 2 columns]

# %% [markdown]
# ### Total Session Duration

# %% [markdown]
# The session duration is acquired by summing up all session times per individual user

# %%
aggFunc.aggregateSumTwo('MSISDN/Number','Dur. (ms).1','Dur. (ms).1',10)
# Out:
#                Dur. (ms).1
# MSISDN/Number
# 3.362578e+10     185537.54
# 3.361489e+10      99668.98
# 3.376054e+10      92794.34
# 3.366716e+10      91578.46
# 3.362632e+10      87919.27
# 3.366284e+10      66142.70
# 3.366469e+10      62887.30
# 3.360313e+10      62877.61
# 3.366746e+10      56498.82
# 3.376041e+10      53216.67

# %% [markdown]
# ### Total Session Traffic

# %%
aggFunc.aggregateSumTwo('MSISDN/Number','Total Session (Mbs)','Total Session (Mbs)',10)
# Out:
#                Total Session (Mbs)
# MSISDN/Number
# 3.361489e+10          15584.491763
# 3.362632e+10          15255.588619
# 3.362578e+10          14020.226793
# 3.367588e+10          13881.859133
# 3.365973e+10          13245.023117
# 3.376054e+10          12497.722857
# 3.366646e+10          11034.684769
# 3.362695e+10          11031.452587
# 3.366716e+10          10866.008883
# 3.365836e+10          10832.002024

# %%
data.columns
# Out:
# Index(['Bearer Id', 'Start', 'Dur. (ms)', 'IMSI', 'MSISDN/Number', 'IMEI',
#        'Last Location Name', 'Avg RTT DL (ms)', 'Avg RTT UL (ms)',
#        'Avg Bearer TP DL (kbps)', 'Avg Bearer TP UL (kbps)',
#        'TCP DL Retrans. Vol (Bytes)', 'TCP UL Retrans. Vol (Bytes)',
#        'HTTP DL (Bytes)', 'HTTP UL (Bytes)', 'Activity Duration DL (ms)',
#        'Activity Duration UL (ms)', 'Dur. (ms).1', 'Handset Manufacturer',
#        'Handset Type', 'Social Media DL (Bytes)', 'Social Media UL (Bytes)',
#        'Google DL (Bytes)', 'Google UL (Bytes)', 'Email DL (Bytes)',
#        'Email UL (Bytes)', 'Youtube DL (Bytes)', 'Youtube UL (Bytes)',
#        'Netflix DL (Bytes)', 'Netflix UL (Bytes)', 'Gaming DL (Bytes)',
#        'Gaming UL (Bytes)', 'Other DL (Bytes)', 'Other UL (Bytes)',
#        'Total UL (Bytes)', 'Total DL (Bytes)', 'Social Media Total (Bytes)',
#        'Google Total (Bytes)', 'Email Total (Bytes)', 'Youtube Total (Bytes)',
#        'Netflix Total (Bytes)', 'Gaming Total (Bytes)', 'Other Total (Bytes)',
#        'Avg Bearer TP DL (Mbps)', 'Avg Bearer TP UL (Mbps)',
#        'Activity Duration DL (s)', 'Activity Duration UL (s)',
#        'Total UL+DL (Bytes)', 'Total Session (Mbs)', 'Duration Class'],
#       dtype='object')

# %%
#create a new dataFrame with 
data2=data.groupby(['MSISDN/Number','Handset Type','IMEI','Last Location Name','IMSI','Handset Manufacturer']).agg({'Bearer Id':'count','Dur. (ms).1':sum,'Avg RTT DL (ms)':sum,'Avg RTT UL (ms)':sum,'Avg Bearer TP DL (kbps)':sum,'Avg Bearer TP UL (kbps)':sum,'TCP DL Retrans. Vol (Bytes)':sum,'TCP UL Retrans. Vol (Bytes)':sum,'HTTP DL (Bytes)':sum,'HTTP UL (Bytes)':sum,'Activity Duration DL (ms)':sum,'Activity Duration UL (ms)':sum,'Social Media DL (Bytes)':sum,'Social Media UL (Bytes)':sum,'Google DL (Bytes)':sum,'Google UL (Bytes)':sum,'Email DL (Bytes)':sum,'Email UL (Bytes)':sum,'Youtube DL (Bytes)':sum,'Youtube UL (Bytes)':sum,'Netflix DL (Bytes)':sum,'Netflix UL (Bytes)':sum,'Gaming DL (Bytes)':sum,'Gaming UL (Bytes)':sum,'Other DL (Bytes)':sum,'Other UL (Bytes)':sum,'Total UL (Bytes)':sum,'Total DL (Bytes)':sum,'Social Media Total (Bytes)':sum,'Google Total (Bytes)':sum,'Email Total (Bytes)':sum,'Youtube Total (Bytes)':sum,'Netflix Total (Bytes)':sum,'Gaming Total (Bytes)':sum,'Other Total (Bytes)':sum,'Avg Bearer TP DL (Mbps)':sum,'Avg Bearer TP UL (Mbps)':sum,'Avg Bearer TP UL (Mbps)':sum,'Activity Duration DL (s)':sum,'Activity Duration UL (s)':sum,'Total UL+DL (Bytes)':sum,'Total Session (Mbs)':sum}).reset_index()

data2
# Out:
#         MSISDN/Number                      Handset Type          IMEI  \
# 0        3.360100e+10    Huawei P20 Lite Huawei Nova 3E  8.627420e+13
# 1        3.360100e+10            Apple iPhone 7 (A1778)  3.553261e+13
# 2        3.360100e+10                         undefined  3.561271e+13
# 3        3.360101e+10           Apple iPhone 5S (A1457)  3.520491e+13
# 4        3.360101e+10           Apple iPhone Se (A1723)  3.530681e+13
# ...               ...                               ...           ...
# 119024   3.379000e+10               Huawei Honor 9 Lite  8.687980e+13
# 119025   3.379000e+10       Apple iPhone 8 Plus (A1897)  3.529761e+13
# 119026   3.197021e+12  Quectel Wireless. Quectel Ec25-E  8.667580e+13
# 119027   3.370000e+14                  Huawei B525S-23A  8.619200e+13
# 119028   8.823971e+14  Quectel Wireless. Quectel Ec21-E  8.679620e+13
#
#        Last Location Name          IMSI               Handset Manufacturer  \
# 0                 L74538A  2.082014e+14                             Huawei
# 1                 D12741B  2.082015e+14                              Apple
# 2                 L96414B  2.082019e+14                          undefined
# 3                 D93721A  2.082017e+14                              Apple
# 4                 D54104C  2.082015e+14                              Apple
# ...                   ...           ...                                ...
# 119024            T93842C  2.082014e+14                             Huawei
# 119025            D42155B  2.082010e+14                              Apple
# 119026            L70386B  2.040808e+14  Quectel Wireless Solutions Co Ltd
# 119027            T89979A  2.082095e+14                             Huawei
# 119028            T31980A  2.040471e+14  Quectel Wireless Solutions Co Ltd
#
#         Bearer Id  Dur. (ms).1  Avg RTT DL (ms)  Avg RTT UL (ms)  ...  \
# 0               1      1167.20        46.000000         0.000000  ...
# 1               1      1812.30        30.000000         1.000000  ...
# 2               1      1349.69       109.795706        17.662883  ...
# 3               1       498.78        69.000000        15.000000  ...
# 4               2       371.04       114.000000         5.000000  ...
# ...           ...          ...              ...              ...  ...
# 119024          1        88.10        42.000000        10.000000  ...
# 119025          1      1409.88        34.000000         6.000000  ...
# 119026          1      8773.85       109.795706        17.662883  ...
# 119027          1      2530.30       109.795706        17.662883  ...
# 119028          1      8698.44       109.795706        17.662883  ...
#
#         Youtube Total (Bytes)  Netflix Total (Bytes)  Gaming Total (Bytes)  \
# 0                  21624548.0             27180981.0          8.124587e+08
# 1                  12432223.0             11221763.0          1.197501e+08
# 2                  21333570.0             19353900.0          5.388277e+08
# 3                   6977321.0              1942092.0          3.911261e+08
# 4                  41533002.0             49201724.0          1.314798e+09
# ...                       ...                    ...                   ...
# 119024             26647843.0             14902538.0          6.603614e+08
# 119025             19851572.0              8531060.0          4.370033e+08
# 119026             11959905.0             26592300.0          1.780487e+08
# 119027             36734940.0             30905042.0          5.101427e+08
# 119028             40940710.0             28846230.0          4.307026e+07
#
#         Other Total (Bytes)  Avg Bearer TP DL (Mbps)  Avg Bearer TP UL (Mbps)  \
# 0               386570872.0                 0.036133                 0.038086
# 1               281710071.0                 0.046875                 0.049805
# 2               501693672.0                 0.046875                 0.047852
# 3                35279702.0                 0.199219                 0.042969
# 4               804804484.0                39.448242                16.063477
# ...                     ...                      ...                      ...
# 119024          295282817.0                 9.744141                 0.377930
# 119025          211115113.0                 0.066406                 0.046875
# 119026          470526473.0                 0.000977                 0.000000
# 119027          149188439.0                 0.010742                 0.021484
# 119028          401360457.0                 0.001953                 0.000000
#
#         Activity Duration DL (s)  Activity Duration UL (s)  \
# 0                         26.588                    33.662
# 1                         49.283                    54.751
# 2                         16.793                    18.434
# 3                         12.097                     4.497
# 4                       4642.908                  3133.148
# ...                          ...                       ...
# 119024                   259.862                   241.044
# 119025                    33.435                    39.006
# 119026                     0.000                     0.000
# 119027                     8.829                    10.540
# 119028                     0.000                     0.000
#
#         Total UL+DL (Bytes)  Total Session (Mbs)
# 0              8.786906e+08          1197.612347
# 1              1.568596e+08           416.200012
# 2              5.959665e+08          1040.509209
# 3              4.223207e+08           426.834773
# 4              1.457411e+09          2131.514222
# ...                     ...                  ...
# 119024         7.146416e+08           959.427761
# 119025         4.803073e+08           653.212936
# 119026         2.321240e+08           667.383262
# 119027         5.962878e+08           706.331140
# 119028         1.391536e+08           503.838888
#
# [119029 rows x 47 columns]

# %% [markdown]
# ## Kmeans Classifier

# %% [markdown]
# We create a new dataframe containing all the above metrics per user

# %%
aggData=data[['Dur. (ms).1','Total Session (Mbs)','MSISDN/Number']]

# %%
aggData
# Out:
#          Dur. (ms).1  Total Session (Mbs)  MSISDN/Number
# 0       18236.520000           493.406131   3.366496e+10
# 1       13651.040000          1176.919550   3.368185e+10
# 2       13617.620000           685.103951   3.376063e+10
# 3       13215.090000          1562.493020   3.375034e+10
# 4       10890.090000          1104.727653   3.369980e+10
# ...              ...                  ...            ...
# 149996    812.300000           605.648632   3.365069e+10
# 149997    979.700000          1352.276146   3.366345e+10
# 149998    982.490000           714.110837   3.362189e+10
# 149999    979.100000          1159.892205   3.361962e+10
# 150000   1046.085603           874.390774   3.361962e+10
#
# [150001 rows x 3 columns]

# %%
# No of xDR sessions
aggrData=data.groupby(['MSISDN/Number']).agg({'Dur. (ms).1':sum,'Total Session (Mbs)':sum,'Bearer Id':'count'})
aggrData=aggrData.rename(columns={'Bearer Id': 'No Sessions'})
aggrData
# Out:
#                Dur. (ms).1  Total Session (Mbs)  No Sessions
# MSISDN/Number
# 3.360100e+10       1167.20          1197.612347            1
# 3.360100e+10       1812.30           416.200012            1
# 3.360100e+10       1349.69          1040.509209            1
# 3.360101e+10        498.78           426.834773            1
# 3.360101e+10        371.04          2131.514222            2
# ...                    ...                  ...          ...
# 3.379000e+10         88.10           959.427761            1
# 3.379000e+10       1409.88           653.212936            1
# 3.197021e+12       8773.85           667.383262            1
# 3.370000e+14       2530.30           706.331140            1
# 8.823971e+14       8698.44           503.838888            1
#
# [106856 rows x 3 columns]

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150001 entries, 0 to 150000
# Data columns (total 50 columns):
#  #   Column                       Non-Null Count   Dtype
# ---  ------                       --------------   -----
#  0   Bearer Id                    150001 non-null  object
#  1   Start                        150001 non-null  object
#  2   Dur. (ms)                    150001 non-null  float64
#  3   IMSI                         150001 non-null  float64
#  4   MSISDN/Number                150001 non-null  float64
#  5   IMEI                         150001 non-null  float64
#  6   Last Location Name           150001 non-null  object
#  7   Avg RTT DL (ms)              150001 non-null  float64
#  8   Avg RTT UL (ms)              150001 non-null  float64
#  9   Avg Bearer TP DL (kbps)      150001 non-null  float64
#  10  Avg Bearer TP UL (kbps)      150001 non-null  float64
#  11  TCP DL Retrans. Vol (Bytes)  150001 non-null  float64
#  12  TCP UL Retrans. Vol (Bytes)  150001 non-null  float64
#  13  HTTP DL (Bytes)              150001 non-null  float64
#  14  HTTP UL (Bytes)              150001 non-null  float64
#  15  Activity Duration DL (ms)    150001 non-null  float64
#  16  Activity Duration UL (ms)    150001 non-null  float64
#  17  Dur. (ms).1                  150001 non-null  float64
#  18  Handset Manufacturer         150001 non-null  object
#  19  Handset Type                 150001 non-null  object
#  20  Social Media DL (Bytes)      150001 non-null  float64
#  21  Social Media UL (Bytes)      150001 non-null  float64
#  22  Google DL (Bytes)            150001 non-null  float64
#  23  Google UL (Bytes)            150001 non-null  float64
#  24  Email DL (Bytes)             150001 non-null  float64
#  25  Email UL (Bytes)             150001 non-null  float64
#  26  Youtube DL (Bytes)           150001 non-null  float64
#  27  Youtube UL (Bytes)           150001 non-null  float64
#  28  Netflix DL (Bytes)           150001 non-null  float64
#  29  Netflix UL (Bytes)           150001 non-null  float64
#  30  Gaming DL (Bytes)            150001 non-null  float64
#  31  Gaming UL (Bytes)            150001 non-null  float64
#  32  Other DL (Bytes)             150001 non-null  float64
#  33  Other UL (Bytes)             150001 non-null  float64
#  34  Total UL (Bytes)             150001 non-null  float64
#  35  Total DL (Bytes)             150001 non-null  float64
#  36  Social Media Total (Bytes)   150001 non-null  float64
#  37  Google Total (Bytes)         150001 non-null  float64
#  38  Email Total (Bytes)          150001 non-null  float64
#  39  Youtube Total (Bytes)        150001 non-null  float64
#  40  Netflix Total (Bytes)        150001 non-null  float64
#  41  Gaming Total (Bytes)         150001 non-null  float64
#  42  Other Total (Bytes)          150001 non-null  float64
#  43  Avg Bearer TP DL (Mbps)      150001 non-null  float64
#  44  Avg Bearer TP UL (Mbps)      150001 non-null  float64
#  45  Activity Duration DL (s)     150001 non-null  float64
#  46  Activity Duration UL (s)     150001 non-null  float64
#  47  Total UL+DL (Bytes)          150001 non-null  float64
#  48  Total Session (Mbs)          150001 non-null  float64
#  49  Duration Class               150001 non-null  object
# dtypes: float64(44), object(6)
# memory usage: 57.2+ MB

# %%
data.columns
# Out:
# Index(['Bearer Id', 'Start', 'Dur. (ms)', 'IMSI', 'MSISDN/Number', 'IMEI',
#        'Last Location Name', 'Avg RTT DL (ms)', 'Avg RTT UL (ms)',
#        'Avg Bearer TP DL (kbps)', 'Avg Bearer TP UL (kbps)',
#        'TCP DL Retrans. Vol (Bytes)', 'TCP UL Retrans. Vol (Bytes)',
#        'HTTP DL (Bytes)', 'HTTP UL (Bytes)', 'Activity Duration DL (ms)',
#        'Activity Duration UL (ms)', 'Dur. (ms).1', 'Handset Manufacturer',
#        'Handset Type', 'Social Media DL (Bytes)', 'Social Media UL (Bytes)',
#        'Google DL (Bytes)', 'Google UL (Bytes)', 'Email DL (Bytes)',
#        'Email UL (Bytes)', 'Youtube DL (Bytes)', 'Youtube UL (Bytes)',
#        'Netflix DL (Bytes)', 'Netflix UL (Bytes)', 'Gaming DL (Bytes)',
#        'Gaming UL (Bytes)', 'Other DL (Bytes)', 'Other UL (Bytes)',
#        'Total UL (Bytes)', 'Total DL (Bytes)', 'Social Media Total (Bytes)',
#        'Google Total (Bytes)', 'Email Total (Bytes)', 'Youtube Total (Bytes)',
#        'Netflix Total (Bytes)', 'Gaming Total (Bytes)', 'Other Total (Bytes)',
#        'Avg Bearer TP DL (Mbps)', 'Avg Bearer TP UL (Mbps)',
#        'Activity Duration DL (s)', 'Activity Duration UL (s)',
#        'Total UL+DL (Bytes)', 'Total Session (Mbs)', 'Duration Class'],
#       dtype='object')

# %%
# newData=pd.merge(aggData,sessionDF,on='MSISDN/Number')

# %%
# aggData=aggData.groupby(['MSISDN/Number']).agg({'Dur. (ms).1':sum,'Total Session (Mbs)':sum})

# %%
# aggreDf=pd.merge(aggData,sessionDF,on='MSISDN/Number')
# aggreDf

# %%
# aggreDf=newData.groupby(['MSISDN/Number']).agg({'Dur. (ms).1':sum,'Total Session (Mbs)':sum,'No of xDR sessions':sum})

# %%
skewedData=aggrData[['Dur. (ms).1','Total Session (Mbs)','No Sessions']]

# %%
skewedData
# Out:
#                Dur. (ms).1  Total Session (Mbs)  No Sessions
# MSISDN/Number
# 3.360100e+10       1167.20          1197.612347            1
# 3.360100e+10       1812.30           416.200012            1
# 3.360100e+10       1349.69          1040.509209            1
# 3.360101e+10        498.78           426.834773            1
# 3.360101e+10        371.04          2131.514222            2
# ...                    ...                  ...          ...
# 3.379000e+10         88.10           959.427761            1
# 3.379000e+10       1409.88           653.212936            1
# 3.197021e+12       8773.85           667.383262            1
# 3.370000e+14       2530.30           706.331140            1
# 8.823971e+14       8698.44           503.838888            1
#
# [106856 rows x 3 columns]

# %%
#we need to scale our data before we can pass it to the model
from sklearn.preprocessing import MinMaxScaler,StandardScaler
minMax=MinMaxScaler()
ss=StandardScaler()
normalizedData=ss.fit_transform(skewedData)

# %%
normalizedData
# Out:
# array([[-0.16089109, -0.03685698, -0.49499518],
#        [ 0.18363006, -1.00237154, -0.49499518],
#        [-0.06343075, -0.23097391, -0.49499518],
#        ...,
#        [ 3.90150513, -0.69200904, -0.49499518],
#        [ 0.56708407, -0.64388497, -0.49499518],
#        [ 3.86123178, -0.89408478, -0.49499518]])

# %%
#we fit a pca for dimensionality reduction to two 
from sklearn.decomposition import PCA

pca = PCA(n_components=2)
pcaData=pca.fit_transform(normalizedData)

# %% [markdown]
# #### Visual Clusters

# %% [markdown]
# Visual representation of clusters from the pca data after classification

# %%
knn=Models(pcaData)
knn.visualizePlot(3,'b',cmap='RdPu')

# %%
predictions=knn.knnPreds(3)
np.unique(predictions)
# Out:
# array([0, 1, 2])

# %% [markdown]
# Our data has been classified into 3 distinct classess

# %% [markdown]
# ## Skewed Data Clusters

# %% [markdown]
# Compute the minimum, maximum, average & total non- normalized metrics for each cluster. Interpret your results visually with accompanying text explaining your findings.

# %%
knn=Models(skewedData)
clusters=knn.knnPreds(3)

# %%
clusters
# Out:
# array([0, 0, 0, ..., 2, 0, 2])

# %%
skewedData['Engagement Cluster']=clusters

# results=data2.merge(skewedData,how='left')

# %%
#we calculate number of users per cluster
(unique, counts) = np.unique(predictions, return_counts=True)
frequencies = np.asarray((unique, counts)).T
frequencies
# Out:
# array([[    0, 78321],
#        [    1, 24788],
#        [    2,  3747]], dtype=int64)

# %%
skewedData.reset_index()
# Out:
#         MSISDN/Number  Dur. (ms).1  Total Session (Mbs)  No Sessions  clusters
# 0        3.360100e+10      1167.20          1197.612347            1         0
# 1        3.360100e+10      1812.30           416.200012            1         0
# 2        3.360100e+10      1349.69          1040.509209            1         0
# 3        3.360101e+10       498.78           426.834773            1         0
# 4        3.360101e+10       371.04          2131.514222            2         0
# ...               ...          ...                  ...          ...       ...
# 106851   3.379000e+10        88.10           959.427761            1         0
# 106852   3.379000e+10      1409.88           653.212936            1         0
# 106853   3.197021e+12      8773.85           667.383262            1         2
# 106854   3.370000e+14      2530.30           706.331140            1         0
# 106855   8.823971e+14      8698.44           503.838888            1         2
#
# [106856 rows x 5 columns]

# %%
clusterDF=skewedData[['MSISDN/Number','Engagement Cluster']]

# %%
# Out:
#         MSISDN/Number  Dur. (ms).1_x  Total Session (Mbs)_x  No Sessions  \
# 0        3.360100e+10        1167.20            1197.612347            1
# 1        3.360100e+10        1812.30             416.200012            1
# 2        3.360100e+10        1349.69            1040.509209            1
# 3        3.360101e+10         498.78             426.834773            1
# 4        3.360101e+10         371.04            2131.514222            2
# ...               ...            ...                    ...          ...
# 119024   3.379000e+10          88.10             959.427761            1
# 119025   3.379000e+10        1409.88             653.212936            1
# 119026   3.197021e+12        8773.85             667.383262            1
# 119027   3.370000e+14        2530.30             706.331140            1
# 119028   8.823971e+14        8698.44             503.838888            1
#
#         clusters                      Handset Type          IMEI  \
# 0              0    Huawei P20 Lite Huawei Nova 3E  8.627420e+13
# 1              0            Apple iPhone 7 (A1778)  3.553261e+13
# 2              0                         undefined  3.561271e+13
# 3              0           Apple iPhone 5S (A1457)  3.520491e+13
# 4              0           Apple iPhone Se (A1723)  3.530681e+13
# ...          ...                               ...           ...
# 119024         0               Huawei Honor 9 Lite  8.687980e+13
# 119025         0       Apple iPhone 8 Plus (A1897)  3.529761e+13
# 119026         2  Quectel Wireless. Quectel Ec25-E  8.667580e+13
# 119027         0                  Huawei B525S-23A  8.619200e+13
# 119028         2  Quectel Wireless. Quectel Ec21-E  8.679620e+13
#
#        Last Location Name          IMSI               Handset Manufacturer  \
# 0                 L74538A  2.082014e+14                             Huawei
# 1                 D12741B  2.082015e+14                              Apple
# 2                 L96414B  2.082019e+14                          undefined
# 3                 D93721A  2.082017e+14                              Apple
# 4                 D54104C  2.082015e+14                              Apple
# ...                   ...           ...                                ...
# 119024            T93842C  2.082014e+14                             Huawei
# 119025            D42155B  2.082010e+14                              Apple
# 119026            L70386B  2.040808e+14  Quectel Wireless Solutions Co Ltd
# 119027            T89979A  2.082095e+14                             Huawei
# 119028            T31980A  2.040471e+14  Quectel Wireless Solutions Co Ltd
#
#         ...  Youtube Total (Bytes)  Netflix Total (Bytes)  \
# 0       ...             21624548.0             27180981.0
# 1       ...             12432223.0             11221763.0
# 2       ...             21333570.0             19353900.0
# 3       ...              6977321.0              1942092.0
# 4       ...             41533002.0             49201724.0
# ...     ...                    ...                    ...
# 119024  ...             26647843.0             14902538.0
# 119025  ...             19851572.0              8531060.0
# 119026  ...             11959905.0             26592300.0
# 119027  ...             36734940.0             30905042.0
# 119028  ...             40940710.0             28846230.0
#
#         Gaming Total (Bytes)  Other Total (Bytes)  Avg Bearer TP DL (Mbps)  \
# 0               8.124587e+08          386570872.0                 0.036133
# 1               1.197501e+08          281710071.0                 0.046875
# 2               5.388277e+08          501693672.0                 0.046875
# 3               3.911261e+08           35279702.0                 0.199219
# 4               1.314798e+09          804804484.0                39.448242
# ...                      ...                  ...                      ...
# 119024          6.603614e+08          295282817.0                 9.744141
# 119025          4.370033e+08          211115113.0                 0.066406
# 119026          1.780487e+08          470526473.0                 0.000977
# 119027          5.101427e+08          149188439.0                 0.010742
# 119028          4.307026e+07          401360457.0                 0.001953
#
#         Avg Bearer TP UL (Mbps)  Activity Duration DL (s)  \
# 0                      0.038086                    26.588
# 1                      0.049805                    49.283
# 2                      0.047852                    16.793
# 3                      0.042969                    12.097
# 4                     16.063477                  4642.908
# ...                         ...                       ...
# 119024                 0.377930                   259.862
# 119025                 0.046875                    33.435
# 119026                 0.000000                     0.000
# 119027                 0.021484                     8.829
# 119028                 0.000000                     0.000
#
#         Activity Duration UL (s)  Total UL+DL (Bytes)  Total Session (Mbs)_y
# 0                         33.662         8.786906e+08            1197.612347
# 1                         54.751         1.568596e+08             416.200012
# 2                         18.434         5.959665e+08            1040.509209
# 3                          4.497         4.223207e+08             426.834773
# 4                       3133.148         1.457411e+09            2131.514222
# ...                          ...                  ...                    ...
# 119024                   241.044         7.146416e+08             959.427761
# 119025                    39.006         4.803073e+08             653.212936
# 119026                     0.000         2.321240e+08             667.383262
# 119027                    10.540         5.962878e+08             706.331140
# 119028                     0.000         1.391536e+08             503.838888
#
# [119029 rows x 51 columns]

# %% [markdown]
# ### Average of Clusters

# %%
skewedData.groupby(['clusters']).agg({'Dur. (ms).1':np.mean,'Total Session (Mbs)':np.mean,'No Sessions':np.mean})
# Out:
#            Dur. (ms).1  Total Session (Mbs)  No Sessions
# clusters
# 0          1050.218036          1039.668108     1.197544
# 1         23182.054437          5666.614180     6.475352
# 2          3877.332252          2419.915626     2.709312

# %%
skewedData.groupby(['clusters']).agg({'Dur. (ms).1':min,'Total Session (Mbs)':min,'No Sessions':min})
# Out:
#           Dur. (ms).1  Total Session (Mbs)  No Sessions
# clusters
# 0               71.42            55.658620            1
# 1             1168.00            92.234064            1
# 2            13222.51           455.162277            1

# %%
skewedData.groupby(['clusters']).agg({'Dur. (ms).1':max,'Total Session (Mbs)':max,'No Sessions':max})
# Out:
#           Dur. (ms).1  Total Session (Mbs)  No Sessions
# clusters
# 0             3183.82          4746.471464            5
# 1            13756.12          8269.153392           11
# 2           185537.54         15584.491763           18

# %%
skewedData.groupby(['clusters']).agg({'Dur. (ms).1':sum,'Total Session (Mbs)':sum,'No Sessions':sum})
# Out:
#            Dur. (ms).1  Total Session (Mbs)  No Sessions
# clusters
# 0         9.765558e+07         9.667474e+07       111355
# 1         5.267356e+07         3.287455e+07        36806
# 2         6.583703e+06         1.609318e+06         1839

# %%
skewedData.groupby(['clusters']).agg({'Dur. (ms).1':sum,'Total Session (Mbs)':sum,'No Sessions':sum}).plot(kind='barh')

# %%
skewedData.groupby(['clusters']).agg({'Dur. (ms).1':max,'Total Session (Mbs)':max,'No Sessions':max}).plot(kind='barh')

# %%
skewedData.groupby(['clusters']).agg({'Dur. (ms).1':min,'Total Session (Mbs)':min,'No Sessions':min}).plot(kind='barh')

# %%
skewedData.groupby(['clusters']).agg({'Dur. (ms).1':np.mean,'Total Session (Mbs)':np.mean,'No Sessions':np.mean}).plot(kind='barh')

# %% [markdown]
# ### Findings

# %% [markdown]
# **Cluster 0** seems to be for people who have fewer number of seesions on average they have the least number of metric averages we can confidently say that this cluster is that of users with the least engagements.
#
# **Cluster 1** can be interprated as the cluster with moderate user engagments. This users fairly use the company's resources to access various platforms on the internet
#
# **Cluster 2** can be identified as heavy user engagments they are user who use the services on a day to day basis and very often

# %% [markdown]
# ## User Engagement per App

# %% [markdown]
# Aggregate user total traffic per application and derive the top 10 most engaged users per application

# %% [markdown]
# ### Total Traffic on all Applications

# %%
data.groupby(['MSISDN/Number']).agg({
    
    'Social Media Total (Bytes)':sum,
    
    'Google Total (Bytes)':sum,
    
    'Email Total (Bytes)':sum,
    
    'Youtube Total (Bytes)':sum,
   
    'Netflix Total (Bytes)':sum,
   
    'Gaming Total (Bytes)':sum,
    
    'Other Total (Bytes)':sum,
    'Total Session (Mbs)':sum
 
    })
# Out:
#                Social Media Total (Bytes)  Google Total (Bytes)  \
# MSISDN/Number
# 3.360100e+10                    2232135.0             4389005.0
# 3.360100e+10                    2660565.0             5334863.0
# 3.360100e+10                    3195623.0             3443126.0
# 3.360101e+10                     280294.0             9678493.0
# 3.360101e+10                    2912542.0            18499616.0
# ...                                   ...                   ...
# 3.379000e+10                     300183.0             7531269.0
# 3.379000e+10                     498569.0             5429705.0
# 3.197021e+12                     715224.0            10438660.0
# 3.370000e+14                     521566.0             9830617.0
# 8.823971e+14                    1546088.0             9218647.0
#
#                Email Total (Bytes)  Youtube Total (Bytes)  \
# MSISDN/Number
# 3.360100e+10             1331362.0             21624548.0
# 3.360100e+10             3307781.0             12432223.0
# 3.360100e+10             3205380.0             21333570.0
# 3.360101e+10             2284670.0              6977321.0
# 3.360101e+10             3305469.0             41533002.0
# ...                            ...                    ...
# 3.379000e+10             1006915.0             26647843.0
# 3.379000e+10             2514097.0             19851572.0
# 3.197021e+12             1520771.0             11959905.0
# 3.370000e+14             3318582.0             36734940.0
# 8.823971e+14             3330974.0             40940710.0
#
#                Netflix Total (Bytes)  Gaming Total (Bytes)  \
# MSISDN/Number
# 3.360100e+10              27180981.0          8.124587e+08
# 3.360100e+10              11221763.0          1.197501e+08
# 3.360100e+10              19353900.0          5.388277e+08
# 3.360101e+10               1942092.0          3.911261e+08
# 3.360101e+10              49201724.0          1.314798e+09
# ...                              ...                   ...
# 3.379000e+10              14902538.0          6.603614e+08
# 3.379000e+10               8531060.0          4.370033e+08
# 3.197021e+12              26592300.0          1.780487e+08
# 3.370000e+14              30905042.0          5.101427e+08
# 8.823971e+14              28846230.0          4.307026e+07
#
#                Other Total (Bytes)  Total Session (Mbs)
# MSISDN/Number
# 3.360100e+10           386570872.0          1197.612347
# 3.360100e+10           281710071.0           416.200012
# 3.360100e+10           501693672.0          1040.509209
# 3.360101e+10            35279702.0           426.834773
# 3.360101e+10           804804484.0          2131.514222
# ...                            ...                  ...
# 3.379000e+10           295282817.0           959.427761
# 3.379000e+10           211115113.0           653.212936
# 3.197021e+12           470526473.0           667.383262
# 3.370000e+14           149188439.0           706.331140
# 8.823971e+14           401360457.0           503.838888
#
# [106856 rows x 8 columns]

# %% [markdown]
# ### Social Media

# %%
aggFunc.aggregateSumTwo('MSISDN/Number','Social Media Total (Bytes)','Social Media Total (Bytes)',10)
# Out:
#                Social Media Total (Bytes)
# MSISDN/Number
# 3.362632e+10                   43374779.0
# 3.376054e+10                   39783189.0
# 3.365973e+10                   35412358.0
# 3.361489e+10                   28294544.0
# 3.366716e+10                   27282716.0
# 3.362578e+10                   27135500.0
# 3.378632e+10                   23974919.0
# 3.366907e+10                   23800834.0
# 3.360313e+10                   23077825.0
# 3.365849e+10                   23000066.0

# %%
data['Application Total (Mbs)']=(data['Social Media Total (Bytes)']+data['Google Total (Bytes)']+data['Email Total (Bytes)']+data['Youtube Total (Bytes)']+data['Netflix Total (Bytes)']+data['Gaming Total (Bytes)']+data['Other Total (Bytes)'])/1024

# %%
data
# Out:
#                    Bearer Id                          Start  Start ms  \
# 0       13114483460844900352            2019-04-04 12:01:18  770.0000
# 1       13114483482878900224            2019-04-09 13:04:04  235.0000
# 2       13114483484080500736            2019-04-09 17:42:11    1.0000
# 3       13114483485442799616            2019-04-10 00:31:25  486.0000
# 4       13114483499480700928            2019-04-12 20:10:23  565.0000
# ...                      ...                            ...       ...
# 149996   7277825670196679680  2019-04-29 07:28:42.000000000  451.0000
# 149997   7349883264234609664  2019-04-29 07:28:42.000000000  483.0000
# 149998  13114483573367300096  2019-04-29 07:28:43.000000000  283.0000
# 149999  13114483573367300096  2019-04-29 07:28:43.000000000  696.0000
# 150000                        2019-04-26 12:36:38.953740032  499.1882
#
#                                   End     End ms     Dur. (ms)          IMSI  \
# 0                 2019-04-25 14:35:31  662.00000  1.823652e+06  2.082014e+14
# 1                 2019-04-25 08:15:48  606.00000  1.365104e+06  2.082019e+14
# 2                 2019-04-25 11:58:13  652.00000  1.361762e+06  2.082003e+14
# 3                 2019-04-25 07:36:35  171.00000  1.321509e+06  2.082014e+14
# 4                 2019-04-25 10:40:32  954.00000  1.089009e+06  2.082014e+14
# ...                               ...        ...           ...           ...
# 149996  2019-04-30 06:02:33.000000000  214.00000  8.123000e+04  2.082022e+14
# 149997  2019-04-30 10:41:33.000000000  187.00000  9.797000e+04  2.082019e+14
# 149998  2019-04-30 10:46:12.000000000  810.00000  9.824900e+04  2.082017e+14
# 149999  2019-04-30 10:40:34.000000000  327.00000  9.791000e+04  2.082021e+14
# 150000  2019-04-27 17:40:08.059673344  498.80088  1.046086e+05           NaN
#
#         MSISDN/Number          IMEI Last Location Name  ...  Hour  \
# 0        3.366496e+10  3.552121e+13   9164566995485190  ...    12
# 1        3.368185e+10  3.579401e+13            L77566A  ...    13
# 2        3.376063e+10  3.528151e+13            D42335A  ...    17
# 3        3.375034e+10  3.535661e+13            T21824A  ...     0
# 4        3.369980e+10  3.540701e+13            D88865A  ...    20
# ...               ...           ...                ...  ...   ...
# 149996   3.365069e+10  3.548311e+13            D20434A  ...     7
# 149997   3.366345e+10  3.566051e+13            D10223C  ...     7
# 149998   3.362189e+10  3.572121e+13            T51102A  ...     7
# 149999   3.361962e+10  8.618620e+13            L88342B  ...     7
# 150000            NaN           NaN                NaN  ...    12
#
#         Avg Bearer TP DL (Mbps)  Avg Bearer TP UL (Mbps)  \
# 0                      0.022461                 0.042969
# 1                      0.015625                 0.025391
# 2                      0.005859                 0.008789
# 3                      0.042969                 0.042969
# 4                      0.005859                 0.008789
# ...                         ...                      ...
# 149996                 0.050781                 0.063477
# 149997                 0.022461                 0.052734
# 149998                 0.041992                 0.045898
# 149999                 0.033203                 0.036133
# 150000                12.988326                 1.728934
#
#         Activity Duration DL (s)  Activity Duration UL (s)  \
# 0                      37.624000                 38.787000
# 1                       0.168000                  3.560000
# 2                       0.000000                  0.000000
# 3                       3.330000                 37.882000
# 4                       0.000000                  0.000000
# ...                          ...                       ...
# 149996                 42.376000                 41.915000
# 149997                 17.264000                 16.759000
# 149998                 25.003000                 28.640000
# 149999                 13.405000                 34.088000
# 150000               1829.176872               1408.879968
#
#         Total Session (Mbs)      five Class  Decile Class  \
# 0                493.406131       Low Usage             1
# 1               1176.919550         Outlier             8
# 2                685.103951  Moderate Usage             2
# 3               1562.493020         Outlier             9
# 4               1104.727653   Extreme Usage             7
# ...                     ...             ...           ...
# 149996           605.648632  Moderate Usage             2
# 149997          1352.276146         Outlier             9
# 149998           714.110837  Moderate Usage             3
# 149999          1159.892205   Extreme Usage             7
# 150000           874.390774      High Usage             4
#
#         Decile Class Category  Application Total (Mbs)
# 0                     Outlier             5.052479e+05
# 1       Moderately High Usage             1.205166e+06
# 2               Extremely Low             7.015464e+05
# 3          Extreme High Usage             1.599993e+06
# 4                  High Usage             1.131241e+06
# ...                       ...                      ...
# 149996          Extremely Low             6.201842e+05
# 149997     Extreme High Usage             1.384731e+06
# 149998         Moderately Low             7.312495e+05
# 149999             High Usage             1.187730e+06
# 150000              Low Usage             8.953762e+05
#
# [150001 rows x 65 columns]

# %%
aggFunc.aggregateSumTwo('MSISDN/Number','Google Total (Bytes)','Google Total (Bytes)',10)
# Out:
#                Google Total (Bytes)
# MSISDN/Number
# 3.362632e+10            152191852.0
# 3.362578e+10            142307915.0
# 3.361489e+10            127973787.0
# 3.376054e+10            123223099.0
# 3.365973e+10            116516345.0
# 3.378632e+10            110254484.0
# 3.367588e+10            109860502.0
# 3.366716e+10            108512588.0
# 3.376127e+10             97089988.0
# 3.369876e+10             91935151.0

# %% [markdown]
# ### Email

# %%
aggFunc.aggregateSumTwo('MSISDN/Number','Email Total (Bytes)','Email Total (Bytes)',10)
# Out:
#                Email Total (Bytes)
# MSISDN/Number
# 3.362632e+10            42418782.0
# 3.361489e+10            40788634.0
# 3.362578e+10            40633966.0
# 3.378632e+10            36310123.0
# 3.365973e+10            35999792.0
# 3.376054e+10            33693767.0
# 3.366716e+10            32349767.0
# 3.367588e+10            31514421.0
# 3.366546e+10            30417885.0
# 3.369879e+10            29059042.0

# %% [markdown]
# ### Youtube

# %%
aggFunc.aggregateSumTwo('MSISDN/Number','Youtube Total (Bytes)','Youtube Total (Bytes)',10)
# Out:
#                Youtube Total (Bytes)
# MSISDN/Number
# 3.362578e+10             452958769.0
# 3.376054e+10             396289198.0
# 3.361489e+10             394370218.0
# 3.362632e+10             374483047.0
# 3.366716e+10             336454560.0
# 3.367588e+10             317410572.0
# 3.362708e+10             308790774.0
# 3.376041e+10             303169107.0
# 3.369879e+10             302661958.0
# 3.360313e+10             284090139.0

# %% [markdown]
# ### Netflix

# %%
aggFunc.aggregateSumTwo('MSISDN/Number','Netflix Total (Bytes)','Netflix Total (Bytes)',10)
# Out:
#                Netflix Total (Bytes)
# MSISDN/Number
# 3.365973e+10             399519079.0
# 3.361489e+10             361401046.0
# 3.362578e+10             356980607.0
# 3.366716e+10             342643175.0
# 3.376054e+10             334643269.0
# 3.362632e+10             328725740.0
# 3.376041e+10             318347546.0
# 3.367588e+10             309093159.0
# 3.378632e+10             305939790.0
# 3.362695e+10             301095984.0

# %% [markdown]
# ### Gaming Totals

# %%
aggFunc.aggregateSumTwo('MSISDN/Number','Gaming Total (Bytes)','Gaming Total (Bytes)',10)
# Out:
#                Gaming Total (Bytes)
# MSISDN/Number
# 3.361489e+10           7.749432e+09
# 3.376054e+10           7.461045e+09
# 3.362578e+10           7.326673e+09
# 3.367588e+10           6.970568e+09
# 3.362632e+10           6.887572e+09
# 3.365973e+10           6.725559e+09
# 3.366646e+10           6.646303e+09
# 3.376041e+10           6.268620e+09
# 3.366471e+10           6.103856e+09
# 3.369879e+10           5.753743e+09

# %% [markdown]
# ### Other

# %%
aggFunc.aggregateSumTwo('MSISDN/Number','Other Total (Bytes)','Other Total (Bytes)',10)
# Out:
#                Other Total (Bytes)
# MSISDN/Number
# 3.362632e+10          8.167878e+09
# 3.361489e+10          7.639264e+09
# 3.367588e+10          6.798515e+09
# 3.362578e+10          6.354583e+09
# 3.360313e+10          6.326671e+09
# 3.365973e+10          6.317415e+09
# 3.362695e+10          6.136537e+09
# 3.362708e+10          5.117791e+09
# 3.366716e+10          5.100796e+09
# 3.376127e+10          5.077779e+09

# %% [markdown]
# ### Total Session Usage

# %%
aggFunc.aggregateSumTwo('MSISDN/Number','Total Session (Mbs)','Total Session (Mbs)',10)
# Out:
#                Total Session (Mbs)
# MSISDN/Number
# 3.361489e+10          15584.491763
# 3.362632e+10          15255.588619
# 3.362578e+10          14020.226793
# 3.367588e+10          13881.859133
# 3.365973e+10          13245.023117
# 3.376054e+10          12497.722857
# 3.366646e+10          11034.684769
# 3.362695e+10          11031.452587
# 3.366716e+10          10866.008883
# 3.365836e+10          10832.002024

# %% [markdown]
# ## Top Three Most Used Applications

# %%
appStats=data[['Social Media Total (Bytes)','Google Total (Bytes)','Email Total (Bytes)','Youtube Total (Bytes)','Netflix Total (Bytes)','Gaming Total (Bytes)','Other Total (Bytes)']]
appTotals=appStats.sum(axis=0)

# %%
appTotals
# Out:
# Social Media Total (Bytes)    2.742394e+11
# Google Total (Bytes)          1.171102e+12
# Email Total (Bytes)           3.388676e+11
# Youtube Total (Bytes)         3.396545e+12
# Netflix Total (Bytes)         3.394314e+12
# Gaming Total (Bytes)          6.455040e+13
# Other Total (Bytes)           6.440523e+13
# dtype: float64

# %%
appDF=pd.DataFrame(appTotals)

# %%
top3=appDF.sort_values(by=0,ascending=False).head(3)

# %%
plt.figure(figsize=(10,7))
sns.barplot(x=top3.index,y=top3[0],palette='rocket')
plt.xticks(rotation=45)
# Out:
# (array([0, 1, 2]), <a list of 3 Text major ticklabel objects>)

# %%
cmap = plt.get_cmap('RdYlGn')
colors = [cmap(i) for i in np.linspace(0, 1, 8)]
plt.figure(figsize=(15,10))
plt.pie(top3,shadow=True,colors=colors,autopct='%1.1f%%',labels=top3.index)
plt.title("Top Three Manufacturers market share")
plt.show()
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:4: MatplotlibDeprecationWarning: Non-1D inputs to pie() are currently squeeze()d, but this behavior is deprecated since 3.1 and will be removed in 3.3; pass a 1D array instead.
#   after removing the cwd from sys.path.

# %%
plt.figure(figsize=(10,7))
sns.boxenplot(x=top3.index,y=top3[0], palette='rainbow')
plt.xticks(rotation=45)
# Out:
# (array([0, 1, 2]), <a list of 3 Text major ticklabel objects>)

# %% [markdown]
# ## Clustering Users

# %%
#using our previously normalized data 
normalizedData
# Out:
# array([[-0.16088588, -0.03684704, -0.49498438],
#        [ 0.1836353 , -1.00236606, -0.49498438],
#        [-0.06342553, -0.23096487, -0.49498438],
#        ...,
#        [ 3.90151073, -0.69200213, -0.49498438],
#        [ 0.56708935, -0.64387783, -0.49498438],
#        [ 3.86123737, -0.8940788 , -0.49498438]])

# %%
# Out:
#                Dur. (ms).1  Total Session (Mbs)  No Sessions
# MSISDN/Number
# 3.360100e+10       1167.20          1197.612347            1
# 3.360100e+10       1812.30           416.200012            1
# 3.360100e+10       1349.69          1040.509209            1
# 3.360101e+10        498.78           426.834773            1
# 3.360101e+10        371.04          2131.514222            2
# ...                    ...                  ...          ...
# 3.379000e+10         88.10           959.427761            1
# 3.379000e+10       1409.88           653.212936            1
# 3.197021e+12       8773.85           667.383262            1
# 3.370000e+14       2530.30           706.331140            1
# 8.823971e+14       8698.44           503.838888            1
#
# [106856 rows x 3 columns]

# %%
from sklearn.cluster import KMeans
Sum_of_squared_distances = []
K = range(1,20)
for k in K:
    km = KMeans(n_clusters=k)
    km = km.fit(normalizedData)
    Sum_of_squared_distances.append(km.inertia_)

# %%
plt.plot(K, Sum_of_squared_distances, 'bx-')
plt.xlabel('k')
plt.ylabel('Sum_of_squared_distances')
plt.title('Elbow Method For Optimal k')
plt.show()

# %% [markdown]
# From the elbow method whereby we seet the k value just before the squared distance error stagnates in this our optimal k value will be 6

# %%
#Lets plot and see how this looks
knn=Models(normalizedData)
knn.visualizePlot(6,'b',cmap='RdPu')

# %%
clusters=knn.knnPreds(6)
clusters
# Out:
# array([0, 3, 0, ..., 2, 3, 1])

# %%
# Out:
#         MSISDN/Number  Bearer Id  Dur. (ms).1  Avg RTT DL (ms)  \
# 6        3.360101e+10          2      1283.60        39.000000
# 7        3.360101e+10          1       863.99        49.000000
# 8        3.360101e+10          2      4957.02       219.591412
# 9        3.360102e+10          1      1248.54        60.000000
# 10       3.360102e+10          1      2484.24        24.000000
# ...               ...        ...          ...              ...
# 106851   3.379000e+10          1        88.10        42.000000
# 106852   3.379000e+10          1      1409.88        34.000000
# 106853   3.197021e+12          1      8773.85       109.795706
# 106854   3.370000e+14          1      2530.30       109.795706
# 106855   8.823971e+14          1      8698.44       109.795706
#
#         Avg RTT UL (ms)  Avg Bearer TP DL (kbps)  Avg Bearer TP UL (kbps)  \
# 6             14.000000                  40971.0                   1542.0
# 7              3.000000                    747.0                    500.0
# 8             35.325766                     77.0                    112.0
# 9              2.000000                     75.0                     71.0
# 10             5.000000                     31.0                     46.0
# ...                 ...                      ...                      ...
# 106851        10.000000                   9978.0                    387.0
# 106852         6.000000                     68.0                     48.0
# 106853        17.662883                      1.0                      0.0
# 106854        17.662883                     11.0                     22.0
# 106855        17.662883                      2.0                      0.0
#
#         TCP DL Retrans. Vol (Bytes)  TCP UL Retrans. Vol (Bytes)  \
# 6                      2.090819e+07                 7.716127e+05
# 7                      2.780000e+02                 7.596587e+05
# 8                      4.161983e+07                 1.519317e+06
# 9                      2.080991e+07                 1.294000e+03
# 10                     2.080991e+07                 7.596587e+05
# ...                             ...                          ...
# 106851                 2.150440e+05                 3.001000e+03
# 106852                 2.080991e+07                 7.596587e+05
# 106853                 2.080991e+07                 7.596587e+05
# 106854                 2.080991e+07                 7.596587e+05
# 106855                 2.080991e+07                 7.596587e+05
#
#         HTTP DL (Bytes)  ...  Youtube Total (Bytes)  Netflix Total (Bytes)  \
# 6          1.183094e+08  ...             26431335.0             45812397.0
# 7          4.524100e+04  ...             18892740.0             15292840.0
# 8          2.289420e+08  ...             63443802.0             54216117.0
# 9          1.144710e+08  ...             28569712.0             35525071.0
# 10         1.144710e+08  ...             15380737.0             20654454.0
# ...                 ...  ...                    ...                    ...
# 106851     6.429450e+05  ...             26647843.0             14902538.0
# 106852     1.144710e+08  ...             19851572.0              8531060.0
# 106853     1.144710e+08  ...             11959905.0             26592300.0
# 106854     1.144710e+08  ...             36734940.0             30905042.0
# 106855     1.144710e+08  ...             40940710.0             28846230.0
#
#         Gaming Total (Bytes)  Other Total (Bytes)  Avg Bearer TP DL (Mbps)  \
# 6                548461057.0         2.248887e+08                40.010742
# 7                282364397.0         1.782015e+08                 0.729492
# 8                833087952.0         1.041883e+09                 0.075195
# 9                647095674.0         1.383392e+08                 0.073242
# 10                55700668.0         5.473911e+08                 0.030273
# ...                      ...                  ...                      ...
# 106851           660361359.0         2.952828e+08                 9.744141
# 106852           437003292.0         2.111151e+08                 0.066406
# 106853           178048738.0         4.705265e+08                 0.000977
# 106854           510142695.0         1.491884e+08                 0.010742
# 106855            43070260.0         4.013605e+08                 0.001953
#
#         Avg Bearer TP UL (Mbps)  Activity Duration DL (s)  \
# 6                      1.505859                  1281.856
# 7                      0.488281                    30.192
# 8                      0.109375                    16.559
# 9                      0.069336                    87.841
# 10                     0.044922                    10.605
# ...                         ...                       ...
# 106851                 0.377930                   259.862
# 106852                 0.046875                    33.435
# 106853                 0.000000                     0.000
# 106854                 0.021484                     8.829
# 106855                 0.000000                     0.000
#
#         Activity Duration UL (s)  Total UL+DL (Bytes)  engagement Cluster
# 6                       1181.052          654723066.0                   2
# 7                         27.951          332660357.0                   0
# 8                         51.002          990132189.0                   2
# 9                         84.036          732463761.0                   0
# 10                        63.739          114976036.0                   0
# ...                          ...                  ...                 ...
# 106851                   241.044          714641641.0                   0
# 106852                    39.006          480307335.0                   0
# 106853                     0.000          232123971.0                   2
# 106854                    10.540          596287824.0                   0
# 106855                     0.000          139153646.0                   0
#
# [106850 rows x 42 columns]

# %%
knn=Models(skewedData)
clusters=knn.knnPreds(6)

# %%
skewedData['Engagement Cluster']=clusters
skewedData.groupby(['Engagement Cluster']).agg({'Dur. (ms).1':np.mean,'Total Session (Mbs)':np.mean,'No Sessions':np.mean})
# Out:
#                      Dur. (ms).1  Total Session (Mbs)  No Sessions
# Engagement Cluster
# 0                     739.462148           935.459641     1.098351
# 1                   28738.275575          6585.934575     7.469027
# 2                   10860.653473          3558.216510     4.081281
# 3                    4021.142637          2718.055782     3.000476
# 4                    1928.816241          1351.419882     1.515658
# 5                   93675.775000         12061.050308    13.875000

# %%
skewedData.reset_index()
# Out:
#         MSISDN/Number  Dur. (ms).1  Total Session (Mbs)  No Sessions  \
# 0        3.360100e+10      1167.20          1197.612347            1
# 1        3.360100e+10      1812.30           416.200012            1
# 2        3.360100e+10      1349.69          1040.509209            1
# 3        3.360101e+10       498.78           426.834773            1
# 4        3.360101e+10       371.04          2131.514222            2
# ...               ...          ...                  ...          ...
# 106851   3.379000e+10        88.10           959.427761            1
# 106852   3.379000e+10      1409.88           653.212936            1
# 106853   3.197021e+12      8773.85           667.383262            1
# 106854   3.370000e+14      2530.30           706.331140            1
# 106855   8.823971e+14      8698.44           503.838888            1
#
#         clusters  Engagement Cluster
# 0              0                   0
# 1              0                   4
# 2              0                   0
# 3              0                   0
# 4              0                   0
# ...          ...                 ...
# 106851         0                   0
# 106852         0                   0
# 106853         2                   2
# 106854         0                   4
# 106855         2                   2
#
# [106856 rows x 6 columns]

# %%
skewedData['MSISDN/Number']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3079             try:
# -> 3080                 return self._engine.get_loc(casted_key)
#    3081             except KeyError as err:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'MSISDN/Number'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-244-c939c8021db7> in <module>
# ----> 1 skewedData['MSISDN/Number']
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    3022             if self.columns.nlevels > 1:
#    3023                 return self._getitem_multilevel(key)
# -> 3024             indexer = self.columns.get_loc(key)
#    3025             if is_integer(indexer):
#    3026                 indexer = [indexer]
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3080                 return self._engine.get_loc(casted_key)
#    3081             except KeyError as err:
# -> 3082                 raise KeyError(key) from err
#    3083
#    3084         if tolerance is not None:
#
# KeyError: 'MSISDN/Number'

# %%
finalCluster=skewedData[['MSISDN/Number','Engagement Cluster']]
finalDF=pd.merge(finalCluster, data2, on='MSISDN/Number')
finalDF
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-243-70b4d2c4478f> in <module>
# ----> 1 finalCluster=skewedData[['MSISDN/Number','Engagement Cluster']]
#       2 finalDF=pd.merge(finalCluster, data2, on='MSISDN/Number')
#       3 finalDF
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    3028             if is_iterator(key):
#    3029                 key = list(key)
# -> 3030             indexer = self.loc._get_listlike_indexer(key, axis=1, raise_missing=True)[1]
#    3031
#    3032         # take() does not accept boolean indexers
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\indexing.py in _get_listlike_indexer(self, key, axis, raise_missing)
#    1264             keyarr, indexer, new_indexer = ax._reindex_non_unique(keyarr)
#    1265
# -> 1266         self._validate_read_indexer(keyarr, indexer, axis, raise_missing=raise_missing)
#    1267         return keyarr, indexer
#    1268
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\indexing.py in _validate_read_indexer(self, key, indexer, axis, raise_missing)
#    1314             if raise_missing:
#    1315                 not_found = list(set(key) - set(ax))
# -> 1316                 raise KeyError(f"{not_found} not in index")
#    1317
#    1318             not_found = key[missing_mask]
#
# KeyError: "['MSISDN/Number'] not in index"

# %%
knn=Models(pcaData)
knn.visualizePlot(3,'b',cmap='RdPu')

# %%
predictions=knn.knnPreds(3)
np.unique(predictions)
finalDF=pd.merge(clusterDF, data2, on='MSISDN/Number')
finalDF

# %%
data2.groupby(['engagement Cluster']).agg({'Dur. (ms).1':np.mean,'Bearer Id':count,'No Sessions':np.mean})
